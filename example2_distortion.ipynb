# %%
import numpy as np
import matplotlib.pyplot as plt
from src.fit import fit_circle
from src.distort import fast_distort
from src.misc import imread, draw_circle

# %%
img = imread('data/sample5.jpg').convert('L')
img = np.array(img)

h0, w0, r = fit_circle(img)

plt.imshow(img, cmap = 'gray')
plt.plot(*draw_circle(h0, w0, r), lw = 3, color = 'orange')
plt.show()

# %%
new_img = fast_distort(img, h0, w0, r, num_iter = 4, filter_size = 9)
plt.imshow(new_img, cmap = 'gray')
plt.show()
